# %%
import pandas_example as pd

db = pd.DataFrame(
    {"Name": ["kishore"], "Id": [1]},
    {"Name": ["Ramesh"], "Id": [2] }
)

print(db)
# Out:
#          Name  Id
# Name  kishore   1
# Id    kishore   1
